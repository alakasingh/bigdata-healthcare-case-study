# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('healthcare_dataset.csv')

# Clean column names (remove spaces)
df.columns = df.columns.str.strip()

print(df.columns)  # check exact column names
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# .
#
# 🔹 Step 1: Gender Distribution
#
# We’ll see how many Male vs Female patients there are.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df, palette='cool')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Patients')
plt.show()
# Out:
# C:\Users\ALAKA\AppData\Local\Temp\ipykernel_16920\575452978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='cool')

# %% [markdown]
# 🔹 Step 2: Age Distribution
#
# We’ll check the age range and most common age groups.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True, color='purple')
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 🔹 Step 3: Average Age by Gender
#
# This helps us see if male or female patients tend to be older.

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Gender', y='Age', data=df, palette='Set2', estimator='mean')
plt.title('Average Age by Gender')
plt.show()
# Out:
# C:\Users\ALAKA\AppData\Local\Temp\ipykernel_16920\3677214615.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Age', data=df, palette='Set2', estimator='mean')
